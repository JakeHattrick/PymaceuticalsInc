# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouseFile = "data/mouse_drug_data.csv"
clinicalFile = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mDF = pd.read_csv(mouseFile)
cDF = pd.read_csv(clinicalFile)

# Combine the data into a single dataset
df = pd.merge(mDF,cDF,'outer')

# Display the data table for preview
df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
groupDF = pd.DataFrame(df.groupby(['Drug','Timepoint'],
                                  as_index=False)['Tumor Volume (mm3)'].mean())

# Convert to DataFrame
groupDF['Tumor Volume (mm3)'] = pd.to_numeric(groupDF['Tumor Volume (mm3)'])
# Preview DataFrame
groupDF.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# 5   Capomulin         25           39.939528
# 6   Capomulin         30           38.769339
# 7   Capomulin         35           37.816839
# 8   Capomulin         40           36.958001
# 9   Capomulin         45           36.236114
# 10   Ceftamin          0           45.000000
# 11   Ceftamin          5           46.503051
# 12   Ceftamin         10           48.285125
# 13   Ceftamin         15           50.094055
# 14   Ceftamin         20           52.157049
# 15   Ceftamin         25           54.287674
# 16   Ceftamin         30           56.769517
# 17   Ceftamin         35           58.827548
# 18   Ceftamin         40           61.467895
# 19   Ceftamin         45           64.132421
# ...

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
#group2DF = pd.DataFrame(df.groupby(['Drug','Timepoint'],
#                                  as_index=False)['Tumor Volume (mm3)'].sem())

# Convert to DataFrame
group2DF = pd.DataFrame(df.groupby(['Drug',
                         'Timepoint'])['Tumor Volume (mm3)'].sem()).reset_index()
# Preview DataFrame
group2DF.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked
meanDF = groupDF.pivot(index='Timepoint',columns = 'Drug',
                        values = 'Tumor Volume (mm3)')
meanDF.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)
tdf = meanDF[['Capomulin','Infubinol','Ketapril','Placebo']]
#tdf.head()
# Save the Figure
plt.plot(tdf['Capomulin'],marker = 'x')
plt.plot(tdf['Infubinol'],marker = 'o')
plt.plot(tdf['Ketapril'],marker = '^')
plt.plot(tdf['Placebo'],marker = 's')
plt.xlabel('Time (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.grid()
plt.legend()
#tdf.plot(grid=True)
plt.title('Tumor Response to Treatment')
plt.savefig('TumorResponseChart.png')

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame
group3DF = pd.DataFrame(df.groupby(['Drug',
                         'Timepoint'])['Metastatic Sites'].mean())
group3DF.reset_index(inplace=True)
group3DF.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.160000
# 2  Capomulin         10          0.320000
# 3  Capomulin         15          0.375000
# 4  Capomulin         20          0.652174

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

group4DF = pd.DataFrame(df.groupby(['Drug',
                         'Timepoint'])['Metastatic Sites'].sem())
group4DF.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked
metadf = group3DF.pivot(index='Timepoint',columns='Drug',values='Metastatic Sites')
metadf.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

tdf2 = metadf[['Capomulin','Infubinol','Ketapril','Placebo']]
plt.plot(tdf2['Capomulin'],marker = 'x')
plt.plot(tdf2['Infubinol'],marker = 'o')
plt.plot(tdf2['Ketapril'],marker = '^')
plt.plot(tdf2['Placebo'],marker = 's')
plt.xlabel('Time (Days)')
plt.ylabel('Metastic Spread')
plt.grid()
plt.legend()
plt.title('Metastatic Spread During Treatment')
plt.savefig('MetastaticChart.png')

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

group5DF = pd.DataFrame(df.groupby(['Drug',
                         'Timepoint'])['Mouse ID'].nunique())
group5DF.rename(columns={'Mouse ID':'Mouse Count'},inplace=True)
group5DF.reset_index(inplace=True)
group5DF.head()
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame
countdf = group5DF.pivot(index='Timepoint', columns = 'Drug',values = 'Mouse Count')
countdf.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                25        25        25         25
# 5                24        25        24         24
# 10               22        24        22         22
# 15               16        24        22         21
# 20               16        23        20         17

# %%
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure

tdf3 = countdf[['Capomulin','Infubinol','Ketapril','Placebo']]
tdf3 = tdf3/25
plt.plot(tdf3['Capomulin'],marker = 'x')
plt.plot(tdf3['Infubinol'],marker = 'o')
plt.plot(tdf3['Ketapril'],marker = '^')
plt.plot(tdf3['Placebo'],marker = 's')
plt.xlabel('Time (Days)')
plt.ylabel('Survival Rate')
plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])
plt.grid()
plt.legend()
plt.title('Survival Rate During Treatment')
plt.savefig('SurvivalChart.png')

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirmS
#sum = df.groupby('Drug')
#sum['Tumor Volume (mm3)'].pct_change()
change = meanDF.pct_change(periods=9).dropna()
for index,row in change.iterrows():
    #change.loc[index] = change.loc[index].map('{:.2%}'.format)
    pass
change
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 45         -0.194753  0.425165   0.461235  0.570288  0.539233  0.51298
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 45         0.472412 -0.223209  0.520851   0.465798

# %%
# Store all Relevant Percent Changes into a Tuple
pchanges = (change.loc[45,'Capomulin'],
           change.loc[45,'Infubinol'],
           change.loc[45,'Ketapril'],
           change.loc[45,'Placebo'])
drugs = ['Capomulin','Infubinol','Ketapril','Placebo']
#c = ['g','r' for x in pchanges if x < 0]
c=['g','r','r','r']
plt.bar(np.arange(len(pchanges)),pchanges,
       width = -.99,align = 'edge',color=c)
plt.xticks(np.arange(len(pchanges)),drugs)
#plt.hlines(0,0,4)
plt.ylim(min(pchanges)*1.08,max(pchanges)*1.05)
plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()])

plt.ylabel('% Tumor Volume Change')
# Splice the data between passing and failing drugs

#pchanges
# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes
for i, v in enumerate(pchanges):
    plt.text(i-.75, v/abs(v)*.05, '{:.2%}'.format(v),
             color='White', fontweight='bold')

# Call functions to implement the function calls


# Save the Figure


# Show the Figure
plt.grid()
plt.title('Tumor Change Over 45 Days Treatment')
plt.savefig('BarChart.png')
#fig.show()
